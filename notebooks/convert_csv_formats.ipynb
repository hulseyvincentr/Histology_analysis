# %%
# -*- coding: utf-8 -*-
"""
Created on Mon Nov 11 21:04:18 2024

@author: heino
"""

import pandas as pd
import ast

rose_dict = {"Image Name": [],
             "Striatum_x_coords":[],
             "Striatum_y_coords":[],
             "Lesion_x_coords":[],
             "Lesion_y_coords":[],
             "Area_X_x_coords":[],
             "Area_X_y_coords":[],
             "LMAN_x_coords":[],
             "LMAN_y_coords":[],
             }

df = pd.read_csv(r"""/Users/mirandahulsey-vincent/Documents/allPythonCode/Histology_analysis/inputs/test_make_ROISs2CSVs/ROIs/PORTED_4.csv""")

expected_regions = ["Area_X.roi", "Striatum.roi", "Lesion.roi", "LMAN.roi"]

unique_image_names = []
all_images_names = []
for i in range(len(df["slide_name"])):
    slide_name = df["slide_name"].iloc[i]
    image_name = slide_name.split(".jpg")[0]
   
    all_images_names.append(image_name)
   
df["image_names"] = all_images_names
   
unique_image_names = df["image_names"].unique()
   
for image_name in unique_image_names:
    img_filter = df["image_names"] == image_name
    df_img = df[img_filter]
   
    regions = list(df_img["region"])

    rose_dict["Image Name"].append(image_name)
    missing_items = list(set(expected_regions) - set(regions))

    for missing_item in missing_items:
        if missing_item == "Area_X.roi":
            rose_dict["Area_X_x_coords"].append("none present")
            rose_dict["Area_X_y_coords"].append("none present")
        if missing_item == "Striatum.roi":
            rose_dict["Striatum_x_coords"].append("none present")
            rose_dict["Striatum_y_coords"].append("none present")
        if missing_item == "Lesion.roi":
            rose_dict["Lesion_x_coords"].append("none present")
            rose_dict["Lesion_y_coords"].append("none present")
        if missing_item == "LMAN.roi":
            rose_dict["LMAN_x_coords"].append("none present")
            rose_dict["LMAN_y_coords"].append("none present")

    for i in range(len(df_img["slide_name"])):
        coords = df_img["coordinates"].iloc[i]
        region = df_img["region"].iloc[i]
       
        print(df_img)
        print(coords[0:10])
        print(region)
        result = ast.literal_eval(coords)

       
        list1, list2 = zip(*result)
       
        if region == "Area_X.roi":
            rose_dict["Area_X_x_coords"].append(list1)
            rose_dict["Area_X_y_coords"].append(list2)
        elif region == "Striatum.roi":
            rose_dict["Striatum_x_coords"].append(list1)
            rose_dict["Striatum_y_coords"].append(list2)
        elif region == "Lesion.roi":
            rose_dict["Lesion_x_coords"].append(list1)
            rose_dict["Lesion_y_coords"].append(list2)
        elif region == "LMAN.roi":
            rose_dict["LMAN_x_coords"].append(list1)
            rose_dict["LMAN_y_coords"].append(list2)
       

df_2 = pd.DataFrame(rose_dict)

df_2.to_csv(r"""/Users/mirandahulsey-vincent/Documents/allPythonCode/Histology_analysis/inputs/test_make_ROISs2CSVs/ROIs/PORTED_4_v2.csv""")
# Out:
#                                     slide_name  \
# 0     042624.01_sect11_NISSL_5x.jpg_Lesion.roi
# 3   042624.01_sect11_NISSL_5x.jpg_Striatum.roi
# 11    042624.01_sect11_NISSL_5x.jpg_Area_X.roi
#
#                                              filename  \
# 0   /Users/mirandahulsey-vincent/Documents/allPyth...
# 3   /Users/mirandahulsey-vincent/Documents/allPyth...
# 11  /Users/mirandahulsey-vincent/Documents/allPyth...
#
#                                           coordinates        region  \
# 0   [(2688, 4296), (2838, 4452), (2898, 4578), (28...    Lesion.roi
# 3   [(4692, 2184), (4686, 2184), (4668, 2184), (46...  Striatum.roi
# 11  [(2016, 3978), (2190, 4032), (2244, 4236), (20...    Area_X.roi
#
#                   image_names
# 0   042624.01_sect11_NISSL_5x
# 3   042624.01_sect11_NISSL_5x
# 11  042624.01_sect11_NISSL_5x
# [(2688, 42
# Lesion.roi
#                                     slide_name  \
# 0     042624.01_sect11_NISSL_5x.jpg_Lesion.roi
# 3   042624.01_sect11_NISSL_5x.jpg_Striatum.roi
# 11    042624.01_sect11_NISSL_5x.jpg_Area_X.roi
#
#                                              filename  \
# 0   /Users/mirandahulsey-vincent/Documents/allPyth...
# 3   /Users/mirandahulsey-vincent/Documents/allPyth...
# 11  /Users/mirandahulsey-vincent/Documents/allPyth...
#
#                                           coordinates        region  \
# 0   [(2688, 4296), (2838, 4452), (2898, 4578), (28...    Lesion.roi
# 3   [(4692, 2184), (4686, 2184), (4668, 2184), (46...  Striatum.roi
# 11  [(2016, 3978), (2190, 4032), (2244, 4236), (20...    Area_X.roi
#
#                   image_names
# 0   042624.01_sect11_NISSL_5x
# 3   042624.01_sect11_NISSL_5x
# 11  042624.01_sect11_NISSL_5x
# [(4692, 21
# Striatum.roi
#                                     slide_name  \
# 0     042624.01_sect11_NISSL_5x.jpg_Lesion.roi
# 3   042624.01_sect11_NISSL_5x.jpg_Striatum.roi
# 11    042624.01_sect11_NISSL_5x.jpg_Area_X.roi
#
#                                              filename  \
# 0   /Users/mirandahulsey-vincent/Documents/allPyth...
# 3   /Users/mirandahulsey-vincent/Documents/allPyth...
# 11  /Users/mirandahulsey-vincent/Documents/allPyth...
#
#                                           coordinates        region  \
# 0   [(2688, 4296), (2838, 4452), (2898, 4578), (28...    Lesion.roi
# 3   [(4692, 2184), (4686, 2184), (4668, 2184), (46...  Striatum.roi
# 11  [(2016, 3978), (2190, 4032), (2244, 4236), (20...    Area_X.roi
#
#                   image_names
# 0   042624.01_sect11_NISSL_5x
# 3   042624.01_sect11_NISSL_5x
# 11  042624.01_sect11_NISSL_5x
# [(2016, 39
# Area_X.roi
#                                     slide_name  \
# 1     042624.01_sect14_NISSL_5x.jpg_Area_X.roi
# 2       042624.01_sect14_NISSL_5x.jpg_LMAN.roi
# 4   042624.01_sect14_NISSL_5x.jpg_Striatum.roi
# 10    042624.01_sect14_NISSL_5x.jpg_Lesion.roi
#
#                                              filename  \
# 1   /Users/mirandahulsey-vincent/Documents/allPyth...
# 2   /Users/mirandahulsey-vincent/Documents/allPyth...
# 4   /Users/mirandahulsey-vincent/Documents/allPyth...
# 10  /Users/mirandahulsey-vincent/Documents/allPyth...
#
#                                           coordinates        region  \
# 1   [(2106, 3078), (2052, 3318), (2346, 3366), (27...    Area_X.roi
# 2   [(1800, 3180), (1548, 3360), (1692, 3456), (18...      LMAN.roi
# 4   [(4296, 1548), (4290, 1548), (4266, 1548), (42...  Striatum.roi
# 10  [(1602, 2640), (2088, 3018), (2688, 3420), (30...    Lesion.roi
#
#                   image_names
# 1   042624.01_sect14_NISSL_5x
# 2   042624.01_sect14_NISSL_5x
# 4   042624.01_sect14_NISSL_5x
# 10  042624.01_sect14_NISSL_5x
# [(2106, 30
# Area_X.roi
#                                     slide_name  \
# 1     042624.01_sect14_NISSL_5x.jpg_Area_X.roi
# 2       042624.01_sect14_NISSL_5x.jpg_LMAN.roi
# 4   042624.01_sect14_NISSL_5x.jpg_Striatum.roi
# 10    042624.01_sect14_NISSL_5x.jpg_Lesion.roi
#
#                                              filename  \
# 1   /Users/mirandahulsey-vincent/Documents/allPyth...
# 2   /Users/mirandahulsey-vincent/Documents/allPyth...
# 4   /Users/mirandahulsey-vincent/Documents/allPyth...
# 10  /Users/mirandahulsey-vincent/Documents/allPyth...
#
#                                           coordinates        region  \
# 1   [(2106, 3078), (2052, 3318), (2346, 3366), (27...    Area_X.roi
# 2   [(1800, 3180), (1548, 3360), (1692, 3456), (18...      LMAN.roi
# 4   [(4296, 1548), (4290, 1548), (4266, 1548), (42...  Striatum.roi
# 10  [(1602, 2640), (2088, 3018), (2688, 3420), (30...    Lesion.roi
#
#                   image_names
# 1   042624.01_sect14_NISSL_5x
# 2   042624.01_sect14_NISSL_5x
# 4   042624.01_sect14_NISSL_5x
# 10  042624.01_sect14_NISSL_5x
# [(1800, 31
# LMAN.roi
#                                     slide_name  \
# 1     042624.01_sect14_NISSL_5x.jpg_Area_X.roi
# 2       042624.01_sect14_NISSL_5x.jpg_LMAN.roi
# 4   042624.01_sect14_NISSL_5x.jpg_Striatum.roi
# 10    042624.01_sect14_NISSL_5x.jpg_Lesion.roi
#
#                                              filename  \
# 1   /Users/mirandahulsey-vincent/Documents/allPyth...
# 2   /Users/mirandahulsey-vincent/Documents/allPyth...
# 4   /Users/mirandahulsey-vincent/Documents/allPyth...
# 10  /Users/mirandahulsey-vincent/Documents/allPyth...
#
#                                           coordinates        region  \
# 1   [(2106, 3078), (2052, 3318), (2346, 3366), (27...    Area_X.roi
# 2   [(1800, 3180), (1548, 3360), (1692, 3456), (18...      LMAN.roi
# 4   [(4296, 1548), (4290, 1548), (4266, 1548), (42...  Striatum.roi
# 10  [(1602, 2640), (2088, 3018), (2688, 3420), (30...    Lesion.roi
#
#                   image_names
# 1   042624.01_sect14_NISSL_5x
# 2   042624.01_sect14_NISSL_5x
# 4   042624.01_sect14_NISSL_5x
# 10  042624.01_sect14_NISSL_5x
# [(4296, 15
# Striatum.roi
#                                     slide_name  \
# 1     042624.01_sect14_NISSL_5x.jpg_Area_X.roi
# 2       042624.01_sect14_NISSL_5x.jpg_LMAN.roi
# 4   042624.01_sect14_NISSL_5x.jpg_Striatum.roi
# 10    042624.01_sect14_NISSL_5x.jpg_Lesion.roi
#
#                                              filename  \
# 1   /Users/mirandahulsey-vincent/Documents/allPyth...
# 2   /Users/mirandahulsey-vincent/Documents/allPyth...
# 4   /Users/mirandahulsey-vincent/Documents/allPyth...
# 10  /Users/mirandahulsey-vincent/Documents/allPyth...
#
#                                           coordinates        region  \
# 1   [(2106, 3078), (2052, 3318), (2346, 3366), (27...    Area_X.roi
# 2   [(1800, 3180), (1548, 3360), (1692, 3456), (18...      LMAN.roi
# 4   [(4296, 1548), (4290, 1548), (4266, 1548), (42...  Striatum.roi
# 10  [(1602, 2640), (2088, 3018), (2688, 3420), (30...    Lesion.roi
#
#                   image_names
# 1   042624.01_sect14_NISSL_5x
# 2   042624.01_sect14_NISSL_5x
# 4   042624.01_sect14_NISSL_5x
# 10  042624.01_sect14_NISSL_5x
# [(1602, 26
# Lesion.roi
#                                     slide_name  \
# 5       042624.01_sect12_NISSL_5x.jpg_LMAN.roi
# 6     042624.01_sect12_NISSL_5x.jpg_Lesion.roi
# 9   042624.01_sect12_NISSL_5x.jpg_Striatum.roi
# 13    042624.01_sect12_NISSL_5x.jpg_Area_X.roi
#
#                                              filename  \
# 5   /Users/mirandahulsey-vincent/Documents/allPyth...
# 6   /Users/mirandahulsey-vincent/Documents/allPyth...
# 9   /Users/mirandahulsey-vincent/Documents/allPyth...
# 13  /Users/mirandahulsey-vincent/Documents/allPyth...
#
#                                           coordinates        region  \
# 5   [(1740, 3882), (1848, 3972), (1848, 4140), (16...      LMAN.roi
# 6   [(2412, 3852), (2634, 4038), (2790, 4194), (28...    Lesion.roi
# 9   [(4632, 2040), (4626, 2040), (4572, 2040), (45...  Striatum.roi
# 13  [(2076, 3786), (2232, 3882), (2238, 4074), (21...    Area_X.roi
#
#                   image_names
# 5   042624.01_sect12_NISSL_5x
# 6   042624.01_sect12_NISSL_5x
# 9   042624.01_sect12_NISSL_5x
# 13  042624.01_sect12_NISSL_5x
# [(1740, 38
# LMAN.roi
#                                     slide_name  \
# 5       042624.01_sect12_NISSL_5x.jpg_LMAN.roi
# 6     042624.01_sect12_NISSL_5x.jpg_Lesion.roi
# 9   042624.01_sect12_NISSL_5x.jpg_Striatum.roi
# 13    042624.01_sect12_NISSL_5x.jpg_Area_X.roi
#
#                                              filename  \
# 5   /Users/mirandahulsey-vincent/Documents/allPyth...
# 6   /Users/mirandahulsey-vincent/Documents/allPyth...
# 9   /Users/mirandahulsey-vincent/Documents/allPyth...
# 13  /Users/mirandahulsey-vincent/Documents/allPyth...
#
#                                           coordinates        region  \
# 5   [(1740, 3882), (1848, 3972), (1848, 4140), (16...      LMAN.roi
# 6   [(2412, 3852), (2634, 4038), (2790, 4194), (28...    Lesion.roi
# 9   [(4632, 2040), (4626, 2040), (4572, 2040), (45...  Striatum.roi
# 13  [(2076, 3786), (2232, 3882), (2238, 4074), (21...    Area_X.roi
#
#                   image_names
# 5   042624.01_sect12_NISSL_5x
# 6   042624.01_sect12_NISSL_5x
# 9   042624.01_sect12_NISSL_5x
# 13  042624.01_sect12_NISSL_5x
# [(2412, 38
# Lesion.roi
#                                     slide_name  \
# 5       042624.01_sect12_NISSL_5x.jpg_LMAN.roi
# 6     042624.01_sect12_NISSL_5x.jpg_Lesion.roi
# 9   042624.01_sect12_NISSL_5x.jpg_Striatum.roi
# 13    042624.01_sect12_NISSL_5x.jpg_Area_X.roi
#
#                                              filename  \
# 5   /Users/mirandahulsey-vincent/Documents/allPyth...
# 6   /Users/mirandahulsey-vincent/Documents/allPyth...
# 9   /Users/mirandahulsey-vincent/Documents/allPyth...
# 13  /Users/mirandahulsey-vincent/Documents/allPyth...
#
#                                           coordinates        region  \
# 5   [(1740, 3882), (1848, 3972), (1848, 4140), (16...      LMAN.roi
# 6   [(2412, 3852), (2634, 4038), (2790, 4194), (28...    Lesion.roi
# 9   [(4632, 2040), (4626, 2040), (4572, 2040), (45...  Striatum.roi
# 13  [(2076, 3786), (2232, 3882), (2238, 4074), (21...    Area_X.roi
#
#                   image_names
# 5   042624.01_sect12_NISSL_5x
# 6   042624.01_sect12_NISSL_5x
# 9   042624.01_sect12_NISSL_5x
# 13  042624.01_sect12_NISSL_5x
# [(4632, 20
# Striatum.roi
#                                     slide_name  \
# 5       042624.01_sect12_NISSL_5x.jpg_LMAN.roi
# 6     042624.01_sect12_NISSL_5x.jpg_Lesion.roi
# 9   042624.01_sect12_NISSL_5x.jpg_Striatum.roi
# 13    042624.01_sect12_NISSL_5x.jpg_Area_X.roi
#
#                                              filename  \
# 5   /Users/mirandahulsey-vincent/Documents/allPyth...
# 6   /Users/mirandahulsey-vincent/Documents/allPyth...
# 9   /Users/mirandahulsey-vincent/Documents/allPyth...
# 13  /Users/mirandahulsey-vincent/Documents/allPyth...
#
#                                           coordinates        region  \
# 5   [(1740, 3882), (1848, 3972), (1848, 4140), (16...      LMAN.roi
# 6   [(2412, 3852), (2634, 4038), (2790, 4194), (28...    Lesion.roi
# 9   [(4632, 2040), (4626, 2040), (4572, 2040), (45...  Striatum.roi
# 13  [(2076, 3786), (2232, 3882), (2238, 4074), (21...    Area_X.roi
#
#                   image_names
# 5   042624.01_sect12_NISSL_5x
# 6   042624.01_sect12_NISSL_5x
# 9   042624.01_sect12_NISSL_5x
# 13  042624.01_sect12_NISSL_5x
# [(2076, 37
# Area_X.roi
#                                     slide_name  \
# 7     042624.01_sect13_NISSL_5x.jpg_Area_X.roi
# 8   042624.01_sect13_NISSL_5x.jpg_Striatum.roi
# 14    042624.01_sect13_NISSL_5x.jpg_Lesion.roi
#
#                                              filename  \
# 7   /Users/mirandahulsey-vincent/Documents/allPyth...
# 8   /Users/mirandahulsey-vincent/Documents/allPyth...
# 14  /Users/mirandahulsey-vincent/Documents/allPyth...
#
#                                           coordinates        region  \
# 7   [(2280, 2712), (2520, 2784), (2568, 3006), (24...    Area_X.roi
# 8   [(1326, 4878), (1326, 4866), (1326, 4806), (13...  Striatum.roi
# 14  [(2196, 2856), (2472, 2976), (2748, 3102), (28...    Lesion.roi
#
#                   image_names
# 7   042624.01_sect13_NISSL_5x
# 8   042624.01_sect13_NISSL_5x
# 14  042624.01_sect13_NISSL_5x
# [(2280, 27
# Area_X.roi
#                                     slide_name  \
# 7     042624.01_sect13_NISSL_5x.jpg_Area_X.roi
# 8   042624.01_sect13_NISSL_5x.jpg_Striatum.roi
# 14    042624.01_sect13_NISSL_5x.jpg_Lesion.roi
#
#                                              filename  \
# 7   /Users/mirandahulsey-vincent/Documents/allPyth...
# 8   /Users/mirandahulsey-vincent/Documents/allPyth...
# 14  /Users/mirandahulsey-vincent/Documents/allPyth...
#
#                                           coordinates        region  \
# 7   [(2280, 2712), (2520, 2784), (2568, 3006), (24...    Area_X.roi
# 8   [(1326, 4878), (1326, 4866), (1326, 4806), (13...  Striatum.roi
# 14  [(2196, 2856), (2472, 2976), (2748, 3102), (28...    Lesion.roi
#
#                   image_names
# 7   042624.01_sect13_NISSL_5x
# 8   042624.01_sect13_NISSL_5x
# 14  042624.01_sect13_NISSL_5x
# [(1326, 48
# Striatum.roi
#                                     slide_name  \
# 7     042624.01_sect13_NISSL_5x.jpg_Area_X.roi
# 8   042624.01_sect13_NISSL_5x.jpg_Striatum.roi
# 14    042624.01_sect13_NISSL_5x.jpg_Lesion.roi
#
#                                              filename  \
# 7   /Users/mirandahulsey-vincent/Documents/allPyth...
# 8   /Users/mirandahulsey-vincent/Documents/allPyth...
# 14  /Users/mirandahulsey-vincent/Documents/allPyth...
#
#                                           coordinates        region  \
# 7   [(2280, 2712), (2520, 2784), (2568, 3006), (24...    Area_X.roi
# 8   [(1326, 4878), (1326, 4866), (1326, 4806), (13...  Striatum.roi
# 14  [(2196, 2856), (2472, 2976), (2748, 3102), (28...    Lesion.roi
#
#                   image_names
# 7   042624.01_sect13_NISSL_5x
# 8   042624.01_sect13_NISSL_5x
# 14  042624.01_sect13_NISSL_5x
# [(2196, 28
# Lesion.roi
#                                     slide_name  \
# 12  042624.01_sect10_NISSL_5x.jpg_Striatum.roi
#
#                                              filename  \
# 12  /Users/mirandahulsey-vincent/Documents/allPyth...
#
#                                           coordinates        region  \
# 12  [(4710, 1926), (4686, 1926), (4656, 1932), (46...  Striatum.roi
#
#                   image_names
# 12  042624.01_sect10_NISSL_5x
# [(4710, 19
# Striatum.roi
